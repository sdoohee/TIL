# %% [markdown]
# ### 크롤링 사이트 연습문제 : 다음 뉴스

# %% [markdown]
# - 'https://news.daum.net' 에서 카드뉴스의 섹션과 제목을 추출해서
# - 데이터프레임으로 생성 후 daum_news_section.csv로 저장

# %% [markdown]
# ![image.png](attachment:62a54872-7b8b-4709-8bce-281038837903.png)

# %%
url = 'https://news.daum.net'
